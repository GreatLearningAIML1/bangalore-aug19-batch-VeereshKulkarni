# %% [markdown]
# ## Train a simple convnet on the Fashion MNIST dataset

# %% [markdown]
# In this, we will see how to deal with image data and train a convnet for image classification task.

# %% [markdown]
# ### Load the  `fashion_mnist`  dataset
#
# ** Use keras.datasets to load the dataset **

# %%
# Setting tensorflow version to 2.x
# %tensorflow_version 2.x 
import tensorflow as tf
print(tf.__version__)
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
import matplotlib.pyplot as plt
from tensorflow.keras import utils

# %%
# Importing fashion_mnist dataset from keras.datasets
from tensorflow.keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# ### Find no.of samples are there in training and test datasets

# %%
print("No. of samples in training dataset :",x_train.shape[0])
print("No. of samples in testing dataset :",x_test.shape[0])
# Out:
# No. of samples in training dataset : 60000
# No. of samples in testing dataset : 10000

# %%
# Examining the dataset
print("Shape of training data:")
print(x_train.shape)
print(y_train.shape)
print("Shape of test data:")
print(x_test.shape)
print(y_test.shape)
# Out:
# Shape of training data:
# (60000, 28, 28)
# (60000,)
# Shape of test data:
# (10000, 28, 28)
# (10000,)

# %% [markdown]
# ### Find dimensions of an image in the dataset

# %%
# Fetch one image data and use shape function to get the dimensions
print("Dimensions of an image in the dataset : ",x_train[0].shape)
# Out:
# Dimensions of an image in the dataset :  (28, 28)

# %%
# Show one of the images from the training dataset
plt.imshow(x_train[0])

# %% [markdown]
# ### Convert train and test labels to one hot vectors
#
# ** check `keras.utils.to_categorical()` **

# %%
# Number of classes = 10 in fashion_MNIST
y_train = utils.to_categorical(y_train, num_classes=10, dtype='float32')
y_test = utils.to_categorical(y_test, num_classes=10, dtype='float32')

# %% [markdown]
# ### Normalize both the train and test image data from 0-255 to 0-1

# %%
# Normalization of pixel values (to [0-1] range)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %% [markdown]
# ### Reshape the data from 28x28 to 28x28x1 to match input dimensions in Conv2D layer in keras

# %%
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1).astype('float32')
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1).astype('float32')

# %% [markdown]
# ### Import the necessary layers from keras to build the model

# %%
from __future__ import absolute_import, division, print_function
import numpy as np

from tensorflow.keras.datasets import cifar10, mnist
from tensorflow.keras.models import Sequential, Model 
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Reshape
from tensorflow.keras.layers import Convolution2D, MaxPooling2D
from tensorflow.keras import backend as k 
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import optimizers

import pickle
from matplotlib import pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (15, 8)

# %% [markdown]
# ### Build a model
#
# ** with 2 Conv layers having `32 3x3 filters` in both convolutions with `relu activations` and `flatten` before passing the feature map into 2 fully connected layers (or Dense Layers) having 128 and 10 neurons with `relu` and `softmax` activations respectively. Now, using `categorical_crossentropy` loss with `adam` optimizer train the model with early stopping `patience=5` and no.of `epochs=10`. **

# %%
# Setting number of epochs & batch size
EPOCHS= 10
BATCH_SIZE= 32

# %%
# Define model
model = Sequential()

# 1st Conv Layer
model.add(Convolution2D(32, 3, 3, input_shape=(28, 28, 1)))
model.add(Activation('relu'))

# 2nd Conv Layer
model.add(Convolution2D(32, 3, 3))
model.add(Activation('relu'))

# Fully Connected Layer
model.add(Flatten())
model.add(Dense(128))
model.add(Activation('relu'))

# Prediction Layer
model.add(Dense(10))
model.add(Activation('softmax'))

# Loss and Optimizer
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Store Training Results
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, verbose=1, mode='auto')
callback_list = [early_stopping]

# Train the model2
history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, 
  validation_data=(x_test, y_test), callbacks=callback_list)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 9s 157us/sample - loss: 0.4991 - accuracy: 0.8204 - val_loss: 0.4070 - val_accuracy: 0.8509
# Epoch 2/10
# 60000/60000 [==============================] - 8s 138us/sample - loss: 0.3440 - accuracy: 0.8741 - val_loss: 0.3555 - val_accuracy: 0.8725
# Epoch 3/10
# 60000/60000 [==============================] - 12s 192us/sample - loss: 0.3024 - accuracy: 0.8883 - val_loss: 0.3208 - val_accuracy: 0.8818
# Epoch 4/10
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.2755 - accuracy: 0.8978 - val_loss: 0.3099 - val_accuracy: 0.8847
# Epoch 5/10
# 60000/60000 [==============================] - 11s 186us/sample - loss: 0.2558 - accuracy: 0.9039 - val_loss: 0.3060 - val_accuracy: 0.8871
# Epoch 6/10
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.2380 - accuracy: 0.9108 - val_loss: 0.2901 - val_accuracy: 0.8949
# Epoch 7/10
# 60000/60000 [==============================] - 10s 167us/sample - loss: 0.2247 - accuracy: 0.9151 - val_loss: 0.3057 - val_accuracy: 0.8873
# Epoch 8/10
# 60000/60000 [==============================] - 11s 186us/sample - loss: 0.2110 - accuracy: 0.9203 - val_loss: 0.2913 - val_accuracy: 0.8913
# Epoch 9/10
# 60000/60000 [==============================] - 11s 191us/sample - loss: 0.1995 - accuracy: 0.9242 - val_loss: 0.2867 - val_accuracy: 0.8985
# Epoch 10/10
# 60000/60000 [==============================] - 10s 169us/sample - loss: 0.1869 - accuracy: 0.9295 - val_loss: 0.2833 - val_accuracy: 0.8978

# %%
loss_and_metrics = model.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print(model.metrics_names)
print(loss_and_metrics)
# Out:
# ['loss', 'accuracy']
# [0.28332850220799444, 0.8978]

# %%
def plotLosses(history):  
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

# %%
plotLosses(history)

# %%
def plotAccuracy(history):  
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

# %%
plotAccuracy(history)

# %% [markdown]
# ### Now, to the above model add `max` pooling layer of `filter size 2x2` and `dropout` layer with `p=0.25` after the 2 conv layers and run the model

# %%
# Setting number of epochs & batch size
BATCH_SIZE = 32
EPOCHS = 10

# %%
# Define Model
model2 = Sequential()

# 1st Conv Layer
model2.add(Convolution2D(32, 3, 3, input_shape=(28, 28, 1)))
model2.add(Activation('relu'))

# 2nd Conv Layer
model2.add(Convolution2D(32, 3, 3))
model2.add(Activation('relu'))

# Max Pooling
model2.add(MaxPooling2D(pool_size=(2,2)))

# Dropout
model2.add(Dropout(0.25))

# Fully Connected Layer
model2.add(Flatten())
model2.add(Dense(128))
model2.add(Activation('relu'))

# Prediction Layer
model2.add(Dense(10))
model2.add(Activation('softmax'))

# Loss and Optimizer
model2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Store Training Results
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, verbose=1, mode='auto')
callback_list = [early_stopping]

# Train the model
history = model2.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, 
  validation_data=(x_test, y_test), callbacks=callback_list)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 9s 156us/sample - loss: 0.9273 - accuracy: 0.6640 - val_loss: 0.6633 - val_accuracy: 0.7604
# Epoch 2/10
# 60000/60000 [==============================] - 9s 151us/sample - loss: 0.6942 - accuracy: 0.7479 - val_loss: 0.5910 - val_accuracy: 0.7859
# Epoch 3/10
# 60000/60000 [==============================] - 9s 149us/sample - loss: 0.6323 - accuracy: 0.7679 - val_loss: 0.5579 - val_accuracy: 0.7998
# Epoch 4/10
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.6043 - accuracy: 0.7802 - val_loss: 0.5362 - val_accuracy: 0.8051
# Epoch 5/10
# 60000/60000 [==============================] - 10s 161us/sample - loss: 0.5799 - accuracy: 0.7872 - val_loss: 0.5241 - val_accuracy: 0.8032
# Epoch 6/10
# 60000/60000 [==============================] - 9s 144us/sample - loss: 0.5651 - accuracy: 0.7907 - val_loss: 0.5096 - val_accuracy: 0.8109
# Epoch 7/10
# 60000/60000 [==============================] - 8s 140us/sample - loss: 0.5547 - accuracy: 0.7942 - val_loss: 0.5063 - val_accuracy: 0.8115
# Epoch 8/10
# 60000/60000 [==============================] - 8s 137us/sample - loss: 0.5417 - accuracy: 0.8012 - val_loss: 0.5049 - val_accuracy: 0.8149
# Epoch 9/10
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.5321 - accuracy: 0.8039 - val_loss: 0.5039 - val_accuracy: 0.8095
# Epoch 10/10
# 60000/60000 [==============================] - 8s 138us/sample - loss: 0.5249 - accuracy: 0.8049 - val_loss: 0.4793 - val_accuracy: 0.8219

# %%
loss_and_metrics = model2.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print(model.metrics_names)
print(loss_and_metrics)
# Out:
# ['loss', 'accuracy']
# [0.4793219255924225, 0.8219]

# %%
plotLosses(history)

# %%
plotAccuracy(history)

# %% [markdown]
# ### Now, to the above model, lets add Data Augmentation

# %% [markdown]
# ### Import the ImageDataGenrator from keras and fit the training images

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# This will do preprocessing and realtime data augmentation:
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    zca_whitening=False,  # apply ZCA whitening
    rotation_range=50,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=False,  # randomly flip images
    vertical_flip=False)  # randomly flip images

# Prepare the generator
datagen.fit(x_train)

# %% [markdown]
# #### Showing 5 versions of the first image in training dataset using image datagenerator.flow()

# %%
from matplotlib import pyplot as plt
gen = datagen.flow(x_train[0:1], batch_size=1)
for i in range(1, 6):
    plt.subplot(1,5,i)
    plt.axis("off")
    plt.imshow(gen.next().squeeze(), cmap='gray')
    plt.plot()
plt.show()

# %% [markdown]
# ### Run the above model using fit_generator()

# %%
BATCH_SIZE = 32
EPOCHS = 10

history = model2.fit_generator(datagen.flow(x_train, y_train,batch_size=BATCH_SIZE),
                    steps_per_epoch=len(x_train)/BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(x_test, y_test), callbacks=callback_list)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 61s 33ms/step - loss: 1.6917 - accuracy: 0.3604 - val_loss: 1.1882 - val_accuracy: 0.5953
# Epoch 2/10
# 1875/1875 [==============================] - 58s 31ms/step - loss: 1.5308 - accuracy: 0.4169 - val_loss: 1.1522 - val_accuracy: 0.6120
# Epoch 3/10
# 1875/1875 [==============================] - 57s 30ms/step - loss: 1.4635 - accuracy: 0.4445 - val_loss: 1.1700 - val_accuracy: 0.5918
# Epoch 4/10
# 1875/1875 [==============================] - 57s 30ms/step - loss: 1.4216 - accuracy: 0.4626 - val_loss: 1.1694 - val_accuracy: 0.5760
# Epoch 5/10
# 1875/1875 [==============================] - 57s 30ms/step - loss: 1.3800 - accuracy: 0.4832 - val_loss: 1.2261 - val_accuracy: 0.5549
# Epoch 6/10
# 1875/1875 [==============================] - 58s 31ms/step - loss: 1.3522 - accuracy: 0.4914 - val_loss: 1.1962 - val_accuracy: 0.5693
# Epoch 7/10
# 1875/1875 [==============================] - 62s 33ms/step - loss: 1.3307 - accuracy: 0.5020 - val_loss: 1.2108 - val_accuracy: 0.5766
# Epoch 00007: early stopping

# %% [markdown]
# ###  Report the final train and validation accuracy

# %%
loss_and_metrics = model2.evaluate(x_train, y_train)
# Out:
# 60000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print(model.metrics_names)
print(loss_and_metrics)
# Out:
# ['loss', 'accuracy']
# [1.1914349877039592, 0.5864]

# %%
plotLosses(history)

# %%
plotAccuracy(history)

# %% [markdown]
# ## **DATA AUGMENTATION ON CIFAR10 DATASET**

# %% [markdown]
# One of the best ways to improve the performance of a Deep Learning model is to add more data to the training set. Aside from gathering more instances from the wild that are representative of the distinction task, we want to develop a set of methods that enhance the data we already have. There are many ways to augment existing datasets and produce more robust models. In the image domain, these are done to utilize the full power of the convolutional neural network, which is able to capture translational invariance. This translational invariance is what makes image recognition such a difficult task in the first place. You want the dataset to be representative of the many different positions, angles, lightings, and miscellaneous distortions that are of interest to the vision task.

# %% [markdown]
# ### **Import neessary libraries for data augmentation**

# %%
# Importing all the necessary libraries for data augmentation

from __future__ import absolute_import, division, print_function
import numpy as np

from tensorflow.keras.datasets import cifar10, mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Reshape
from tensorflow.keras.layers import Convolution2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import utils
import pickle
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.rcParams['figure.figsize'] = (15, 8)

# %% [markdown]
# ### **Load CIFAR10 dataset**

# %%
# Importing CIFAR10 dataset from keras
from tensorflow.keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# Examining the dataset
print("Shape of training data:")
print(x_train.shape)
print(y_train.shape)
print("Shape of test data:")
print(x_test.shape)
print(y_test.shape)
# Out:
# Shape of training data:
# (50000, 32, 32, 3)
# (50000, 1)
# Shape of test data:
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# ### **Create a data_gen funtion to genererator with image rotation,shifting image horizontally and vertically with random flip horizontally.**

# %%
def data_gen():
      # This will do preprocessing and realtime data augmentation:
      datagen = ImageDataGenerator(
      featurewise_center=False,  # set input mean to 0 over the dataset
      samplewise_center=False,  # set each sample mean to 0
      featurewise_std_normalization=False,  # divide inputs by std of the dataset
      samplewise_std_normalization=False,  # divide each input by its std
      zca_whitening=False,  # apply ZCA whitening
      rotation_range=50,  # randomly rotate images in the range (degrees, 0 to 180)
      width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
      height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
      horizontal_flip=True,  # randomly flip images
      vertical_flip=True)  # randomly flip images

      return datagen

# %% [markdown]
# ### **Prepare/fit the generator.**

# %%
# Prepare the generator
datagen = data_gen()
datagen.fit(x_train)

# %% [markdown]
# ### **Generate 5 images for 1 of the image of CIFAR10 train dataset.**

# %%
from matplotlib import pyplot as plt
gen = datagen.flow(x_train[0:1], batch_size=1)
for i in range(1, 6):
    plt.subplot(1,5,i)
    plt.axis("off")
    plt.imshow(gen.next().squeeze().astype('uint8'), cmap=None)
    plt.plot()
plt.show()
