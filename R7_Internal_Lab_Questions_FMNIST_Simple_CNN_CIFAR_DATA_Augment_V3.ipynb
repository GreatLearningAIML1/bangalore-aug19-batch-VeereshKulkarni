# %% [markdown]
# ## Train a simple convnet on the Fashion MNIST dataset

# %% [markdown]
# In this, we will see how to deal with image data and train a convnet for image classification task.

# %% [markdown]
# ### Load the  `fashion_mnist`  dataset
#
# ** Use keras.datasets to load the dataset **

# %%
# Setting tensorflow version to 2.x
# %tensorflow_version 2.x 
import tensorflow as tf
print(tf.__version__)
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
import matplotlib.pyplot as plt
from tensorflow.keras import utils

# %%
# Importing fashion_mnist dataset from keras.datasets
from tensorflow.keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# ### Find no.of samples are there in training and test datasets

# %%
print("No. of samples in training dataset :",x_train.shape[0])
print("No. of samples in testing dataset :",x_test.shape[0])
# Out:
# No. of samples in training dataset : 60000
# No. of samples in testing dataset : 10000

# %%
# Examining the dataset
print("Shape of training data:")
print(x_train.shape)
print(y_train.shape)
print("Shape of test data:")
print(x_test.shape)
print(y_test.shape)
# Out:
# Shape of training data:
# (60000, 28, 28)
# (60000,)
# Shape of test data:
# (10000, 28, 28)
# (10000,)

# %% [markdown]
# ### Find dimensions of an image in the dataset

# %%
# Fetch one image data and use shape function to get the dimensions
print("Dimensions of an image in the dataset : ",x_train[0].shape)
# Out:
# Dimensions of an image in the dataset :  (28, 28)

# %%
# Show one of the images from the training dataset
plt.imshow(x_train[0])

# %% [markdown]
# ### Convert train and test labels to one hot vectors
#
# ** check `keras.utils.to_categorical()` **

# %%
# Number of classes = 10 in fashion_MNIST
# One hot encoding of test and train labels
y_train = utils.to_categorical(y_train, num_classes=10, dtype='float32')
y_test = utils.to_categorical(y_test, num_classes=10, dtype='float32')

# %% [markdown]
# ### Normalize both the train and test image data from 0-255 to 0-1

# %%
# Normalization of pixel values (to [0-1] range)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %% [markdown]
# ### Reshape the data from 28x28 to 28x28x1 to match input dimensions in Conv2D layer in keras

# %%
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1).astype('float32')
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1).astype('float32')

# %%
# check shape
x_train[0].shape
# Out:
# (28, 28, 1)

# %% [markdown]
# ### Import the necessary layers from keras to build the model

# %%
from __future__ import absolute_import, division, print_function
import numpy as np

from tensorflow.keras.datasets import cifar10, mnist
from tensorflow.keras.models import Sequential, Model 
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Reshape
from tensorflow.keras.layers import Convolution2D, MaxPooling2D
from tensorflow.keras import backend as k 
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import optimizers

import pickle
from matplotlib import pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (15, 8)

# %% [markdown]
# ### Build a model
#
# ** with 2 Conv layers having `32 3x3 filters` in both convolutions with `relu activations` and `flatten` before passing the feature map into 2 fully connected layers (or Dense Layers) having 128 and 10 neurons with `relu` and `softmax` activations respectively. Now, using `categorical_crossentropy` loss with `adam` optimizer train the model with early stopping `patience=5` and no.of `epochs=10`. **

# %%
# Setting number of epochs & batch size
EPOCHS= 10
BATCH_SIZE= 32

# %%
# Define model
model = Sequential()

# 1st Conv Layer
model.add(Convolution2D(32, 3, 3, input_shape=(28, 28, 1)))
model.add(Activation('relu'))

# 2nd Conv Layer
model.add(Convolution2D(32, 3, 3))
model.add(Activation('relu'))

# Fully Connected Layer
model.add(Flatten())
model.add(Dense(128))
model.add(Activation('relu'))

# Prediction Layer
model.add(Dense(10))
model.add(Activation('softmax'))

# Loss and Optimizer
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Store Training Results
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, verbose=1, mode='auto')
callback_list = [early_stopping]

# Train the model2
history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, 
  validation_data=(x_test, y_test), callbacks=callback_list)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 11s 192us/sample - loss: 0.5143 - accuracy: 0.8148 - val_loss: 0.3987 - val_accuracy: 0.8578
# Epoch 2/10
# 60000/60000 [==============================] - 9s 154us/sample - loss: 0.3512 - accuracy: 0.8709 - val_loss: 0.3490 - val_accuracy: 0.8727
# Epoch 3/10
# 60000/60000 [==============================] - 9s 147us/sample - loss: 0.3088 - accuracy: 0.8855 - val_loss: 0.3268 - val_accuracy: 0.8800
# Epoch 4/10
# 60000/60000 [==============================] - 9s 147us/sample - loss: 0.2826 - accuracy: 0.8934 - val_loss: 0.3133 - val_accuracy: 0.8852
# Epoch 5/10
# 60000/60000 [==============================] - 9s 148us/sample - loss: 0.2610 - accuracy: 0.9024 - val_loss: 0.3086 - val_accuracy: 0.8860
# Epoch 6/10
# 60000/60000 [==============================] - 9s 150us/sample - loss: 0.2432 - accuracy: 0.9090 - val_loss: 0.3082 - val_accuracy: 0.8893
# Epoch 7/10
# 60000/60000 [==============================] - 9s 147us/sample - loss: 0.2283 - accuracy: 0.9143 - val_loss: 0.2867 - val_accuracy: 0.8958
# Epoch 8/10
# 60000/60000 [==============================] - 9s 148us/sample - loss: 0.2150 - accuracy: 0.9191 - val_loss: 0.2873 - val_accuracy: 0.8989
# Epoch 9/10
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.2039 - accuracy: 0.9236 - val_loss: 0.2844 - val_accuracy: 0.8965
# Epoch 10/10
# 60000/60000 [==============================] - 9s 148us/sample - loss: 0.1923 - accuracy: 0.9276 - val_loss: 0.2783 - val_accuracy: 0.8983

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 9, 9, 32)          320
# _________________________________________________________________
# activation (Activation)      (None, 9, 9, 32)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 3, 3, 32)          9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 3, 3, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 288)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               36992
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# =================================================================
# Total params: 47,850
# Trainable params: 47,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_and_metrics = model.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print(model.metrics_names)
print(loss_and_metrics)
# Out:
# ['loss', 'accuracy']
# [0.27827741820812224, 0.8983]

# %%
def plotLosses(history):  
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

# %%
plotLosses(history)

# %%
def plotAccuracy(history):  
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

# %%
plotAccuracy(history)

# %%
plt.title('Model accuracy of last epoch')
plt.bar('Train',history.history['accuracy'][-1])
plt.bar('Test',history.history['val_accuracy'][-1])
print ('Train accuracy :',history.history['accuracy'][-1])
print ('Test accuracy :',history.history['val_accuracy'][-1])
# Out:
# Train accuracy : 0.92755
# Test accuracy : 0.8983

# %% [markdown]
# ### Now, to the above model add `max` pooling layer of `filter size 2x2` and `dropout` layer with `p=0.25` after the 2 conv layers and run the model

# %%
# Setting number of epochs & batch size
BATCH_SIZE = 32
EPOCHS = 10

# %%
# Define Model
model2 = Sequential()

# 1st Conv Layer
model2.add(Convolution2D(32, 3, 3, input_shape=(28, 28, 1)))
model2.add(Activation('relu'))

# 2nd Conv Layer
model2.add(Convolution2D(32, 3, 3))
model2.add(Activation('relu'))

# Max Pooling
model2.add(MaxPooling2D(pool_size=(2,2)))

# Dropout
model2.add(Dropout(0.25))

# Fully Connected Layer
model2.add(Flatten())
model2.add(Dense(128))
model2.add(Activation('relu'))

# Prediction Layer
model2.add(Dense(10))
model2.add(Activation('softmax'))

# Loss and Optimizer
model2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Store Training Results
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, verbose=1, mode='auto')
callback_list = [early_stopping]

# Train the model
history = model2.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, 
  validation_data=(x_test, y_test), callbacks=callback_list)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 9s 152us/sample - loss: 0.9391 - accuracy: 0.6626 - val_loss: 0.6631 - val_accuracy: 0.7609
# Epoch 2/10
# 60000/60000 [==============================] - 9s 145us/sample - loss: 0.6969 - accuracy: 0.7480 - val_loss: 0.5872 - val_accuracy: 0.7892
# Epoch 3/10
# 60000/60000 [==============================] - 9s 143us/sample - loss: 0.6328 - accuracy: 0.7683 - val_loss: 0.5452 - val_accuracy: 0.8031
# Epoch 4/10
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.5932 - accuracy: 0.7837 - val_loss: 0.5320 - val_accuracy: 0.8032
# Epoch 5/10
# 60000/60000 [==============================] - 8s 142us/sample - loss: 0.5711 - accuracy: 0.7895 - val_loss: 0.5195 - val_accuracy: 0.8123
# Epoch 6/10
# 60000/60000 [==============================] - 8s 142us/sample - loss: 0.5527 - accuracy: 0.7955 - val_loss: 0.4928 - val_accuracy: 0.8165
# Epoch 7/10
# 60000/60000 [==============================] - 9s 144us/sample - loss: 0.5386 - accuracy: 0.8013 - val_loss: 0.4977 - val_accuracy: 0.8133
# Epoch 8/10
# 60000/60000 [==============================] - 9s 145us/sample - loss: 0.5282 - accuracy: 0.8035 - val_loss: 0.4889 - val_accuracy: 0.8158
# Epoch 9/10
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.5157 - accuracy: 0.8097 - val_loss: 0.4881 - val_accuracy: 0.8213
# Epoch 10/10
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.5063 - accuracy: 0.8123 - val_loss: 0.4730 - val_accuracy: 0.8281

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 9, 9, 32)          320
# _________________________________________________________________
# activation_4 (Activation)    (None, 9, 9, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 32)          9248
# _________________________________________________________________
# activation_5 (Activation)    (None, 3, 3, 32)          0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 1, 1, 32)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               4224
# _________________________________________________________________
# activation_6 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation_7 (Activation)    (None, 10)                0
# =================================================================
# Total params: 15,082
# Trainable params: 15,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_and_metrics = model2.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print(model.metrics_names)
print(loss_and_metrics)
# Out:
# ['loss', 'accuracy']
# [0.47298363733291626, 0.8281]

# %%
plotLosses(history)

# %%
plotAccuracy(history)

# %%
plt.title('Model accuracy of last epoch')
plt.bar('Train',history.history['accuracy'][-1])
plt.bar('Test',history.history['val_accuracy'][-1])
print ('Train accuracy :',history.history['accuracy'][-1])
print ('Test accuracy :',history.history['val_accuracy'][-1])
# Out:
# Train accuracy : 0.81233335
# Test accuracy : 0.8281

# %% [markdown]
# ### Now, to the above model, lets add Data Augmentation

# %% [markdown]
# ### Import the ImageDataGenrator from keras and fit the training images

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# This will do preprocessing and realtime data augmentation:
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    zca_whitening=False,  # apply ZCA whitening
    rotation_range=50,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=False,  # randomly flip images
    vertical_flip=False)  # randomly flip images

# Prepare the generator
datagen.fit(x_train)

# %% [markdown]
# #### Showing 5 versions of the first image in training dataset using image datagenerator.flow()

# %%
from matplotlib import pyplot as plt
gen = datagen.flow(x_train[0:1], batch_size=1)
for i in range(1, 6):
    plt.subplot(1,5,i)
    plt.axis("off")
    plt.imshow(gen.next().squeeze(), cmap='gray')
    plt.plot()
plt.show()

# %% [markdown]
# ### Run the above model using fit_generator()

# %%
BATCH_SIZE = 32
EPOCHS = 10

history = model2.fit_generator(datagen.flow(x_train, y_train,batch_size=BATCH_SIZE),
                    steps_per_epoch=len(x_train)/BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(x_test, y_test), callbacks=callback_list)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 55s 29ms/step - loss: 1.6708 - accuracy: 0.3695 - val_loss: 1.1184 - val_accuracy: 0.5995
# Epoch 2/10
# 1875/1875 [==============================] - 58s 31ms/step - loss: 1.5145 - accuracy: 0.4275 - val_loss: 1.1503 - val_accuracy: 0.5779
# Epoch 3/10
# 1875/1875 [==============================] - 58s 31ms/step - loss: 1.4443 - accuracy: 0.4551 - val_loss: 1.1655 - val_accuracy: 0.5833
# Epoch 4/10
# 1875/1875 [==============================] - 59s 31ms/step - loss: 1.4001 - accuracy: 0.4748 - val_loss: 1.2347 - val_accuracy: 0.5479
# Epoch 5/10
# 1875/1875 [==============================] - 59s 31ms/step - loss: 1.3691 - accuracy: 0.4864 - val_loss: 1.1667 - val_accuracy: 0.5794
# Epoch 6/10
# 1875/1875 [==============================] - 59s 31ms/step - loss: 1.3479 - accuracy: 0.4936 - val_loss: 1.2266 - val_accuracy: 0.5367
# Epoch 00006: early stopping

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 9, 9, 32)          320
# _________________________________________________________________
# activation_4 (Activation)    (None, 9, 9, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 32)          9248
# _________________________________________________________________
# activation_5 (Activation)    (None, 3, 3, 32)          0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 1, 1, 32)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               4224
# _________________________________________________________________
# activation_6 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation_7 (Activation)    (None, 10)                0
# =================================================================
# Total params: 15,082
# Trainable params: 15,082
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ###  Report the final train and validation accuracy

# %%
loss_and_metrics = model2.evaluate(x_train, y_train)
# Out:
# 60000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print(model.metrics_names)
print(loss_and_metrics)
# Out:
# ['loss', 'accuracy']
# [1.2133283288955687, 0.54188335]

# %%
plotLosses(history)

# %%
plotAccuracy(history)

# %%
plt.title('Model accuracy of last epoch')
plt.bar('Train',history.history['accuracy'][-1])
plt.bar('Test',history.history['val_accuracy'][-1])
print ('Train accuracy :',history.history['accuracy'][-1])
print ('Test accuracy :',history.history['val_accuracy'][-1])
# Out:
# Train accuracy : 0.49361667
# Test accuracy : 0.5367

# %% [markdown]
# ## **DATA AUGMENTATION ON CIFAR10 DATASET**

# %% [markdown]
# One of the best ways to improve the performance of a Deep Learning model is to add more data to the training set. Aside from gathering more instances from the wild that are representative of the distinction task, we want to develop a set of methods that enhance the data we already have. There are many ways to augment existing datasets and produce more robust models. In the image domain, these are done to utilize the full power of the convolutional neural network, which is able to capture translational invariance. This translational invariance is what makes image recognition such a difficult task in the first place. You want the dataset to be representative of the many different positions, angles, lightings, and miscellaneous distortions that are of interest to the vision task.

# %% [markdown]
# ### **Import neessary libraries for data augmentation**

# %%
# Importing all the necessary libraries for data augmentation

from __future__ import absolute_import, division, print_function
import numpy as np

from tensorflow.keras.datasets import cifar10, mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Reshape
from tensorflow.keras.layers import Convolution2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import utils
import pickle
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.rcParams['figure.figsize'] = (15, 8)

# %% [markdown]
# ### **Load CIFAR10 dataset**

# %%
# Importing CIFAR10 dataset from keras
from tensorflow.keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# Examining the dataset
print("Shape of training data:")
print(x_train.shape)
print(y_train.shape)
print("Shape of test data:")
print(x_test.shape)
print(y_test.shape)
# Out:
# Shape of training data:
# (50000, 32, 32, 3)
# (50000, 1)
# Shape of test data:
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# ### **Create a data_gen funtion to genererator with image rotation,shifting image horizontally and vertically with random flip horizontally.**

# %%
def data_gen():
      # This will do preprocessing and realtime data augmentation:
      datagen = ImageDataGenerator(
      featurewise_center=False,  # set input mean to 0 over the dataset
      samplewise_center=False,  # set each sample mean to 0
      featurewise_std_normalization=False,  # divide inputs by std of the dataset
      samplewise_std_normalization=False,  # divide each input by its std
      zca_whitening=False,  # apply ZCA whitening
      rotation_range=50,  # randomly rotate images in the range (degrees, 0 to 180)
      width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
      height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
      horizontal_flip=True,  # randomly flip images
      vertical_flip=True)  # randomly flip images

      return datagen

# %% [markdown]
# ### **Prepare/fit the generator.**

# %%
# Prepare the generator
datagen = data_gen()
datagen.fit(x_train)

# %% [markdown]
# ### **Generate 5 images for 1 of the image of CIFAR10 train dataset.**

# %%
from matplotlib import pyplot as plt
gen = datagen.flow(x_train[0:1], batch_size=1)
for i in range(1, 6):
    plt.subplot(1,5,i)
    plt.axis("off")
    plt.imshow(gen.next().squeeze().astype('uint8'), cmap=None)
    plt.plot()
plt.show()
